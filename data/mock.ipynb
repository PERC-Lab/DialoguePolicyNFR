# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import cohen_kappa_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # MOCK Ground Truth

# %%
np.random.seed(42)

NUM_NFRS = 20
NUM_PARTICIPANTS = 2

# %%
satisfaction_levels = ['Satisfied', 'Weakly Satisfied', 'Weakly Denied', 'Denied', 'NA']

ground_truth_data = {
    'nfr_id': [f'NFR_{i+1}' for i in range(NUM_NFRS)],
    'satisfaction_level': np.random.choice(satisfaction_levels, NUM_NFRS),
    'reasoning_text': [f'Reasoning for NFR_{i+1}: The system uses encryption and proper authentication.' for i in range(NUM_NFRS)],
    'code_locations': [[f'file_{i}.py:lines_10-20', f'file_{i}.py:lines_45-50'] for i in range(NUM_NFRS)],
}

llm_response_data = {
    'nfr_id': [f'NFR_{i+1}' for i in range(NUM_NFRS)],
    'satisfaction_level': [],
    'reasoning_text': [],
    'code_locations': [],
}

for i in range(NUM_NFRS):
    if np.random.random() < 0.8:
        llm_response_data['satisfaction_level'].append(ground_truth_data['satisfaction_level'][i])
    else:
        other_levels = [l for l in satisfaction_levels if l != ground_truth_data['satisfaction_level'][i]]
        llm_response_data['satisfaction_level'].append(np.random.choice(other_levels))
    
    if np.random.random() < 0.85:
        llm_response_data['reasoning_text'].append(ground_truth_data['reasoning_text'][i])
    else:
        llm_response_data['reasoning_text'].append(f'Reasoning for NFR_{i+1}: Alternative explanation with different focus.')
    
    gt_locations = ground_truth_data['code_locations'][i]
    if np.random.random() < 0.75:
        llm_response_data['code_locations'].append(gt_locations)
    else:
        partial = gt_locations[:1] + [f'file_{i}_wrong.py:lines_30-35']
        llm_response_data['code_locations'].append(partial)

df_ground_truth = pd.DataFrame(ground_truth_data)
df_llm_response = pd.DataFrame(llm_response_data)

# %%
df_ground_truth
# Out:
#     nfr_id satisfaction_level  \
# 0    NFR_1             Denied
# 1    NFR_2                 NA
# 2    NFR_3      Weakly Denied
# 3    NFR_4                 NA
# 4    NFR_5                 NA
# 5    NFR_6   Weakly Satisfied
# 6    NFR_7      Weakly Denied
# 7    NFR_8      Weakly Denied
# 8    NFR_9      Weakly Denied
# 9   NFR_10                 NA
# 10  NFR_11             Denied
# 11  NFR_12      Weakly Denied
# 12  NFR_13                 NA
# 13  NFR_14   Weakly Satisfied
# 14  NFR_15             Denied
# 15  NFR_16   Weakly Satisfied
# 16  NFR_17             Denied
# 17  NFR_18                 NA
# 18  NFR_19          Satisfied
# 19  NFR_20             Denied
#
#                                        reasoning_text  \
# 0   Reasoning for NFR_1: The system uses encryptio...
# 1   Reasoning for NFR_2: The system uses encryptio...
# 2   Reasoning for NFR_3: The system uses encryptio...
# 3   Reasoning for NFR_4: The system uses encryptio...
# 4   Reasoning for NFR_5: The system uses encryptio...
# 5   Reasoning for NFR_6: The system uses encryptio...
# 6   Reasoning for NFR_7: The system uses encryptio...
# 7   Reasoning for NFR_8: The system uses encryptio...
# 8   Reasoning for NFR_9: The system uses encryptio...
# 9   Reasoning for NFR_10: The system uses encrypti...
# 10  Reasoning for NFR_11: The system uses encrypti...
# 11  Reasoning for NFR_12: The system uses encrypti...
# 12  Reasoning for NFR_13: The system uses encrypti...
# 13  Reasoning for NFR_14: The system uses encrypti...
# 14  Reasoning for NFR_15: The system uses encrypti...
# 15  Reasoning for NFR_16: The system uses encrypti...
# 16  Reasoning for NFR_17: The system uses encrypti...
# 17  Reasoning for NFR_18: The system uses encrypti...
# 18  Reasoning for NFR_19: The system uses encrypti...
# 19  Reasoning for NFR_20: The system uses encrypti...
#
#                                       code_locations
# 0     [file_0.py:lines_10-20, file_0.py:lines_45-50]
# 1     [file_1.py:lines_10-20, file_1.py:lines_45-50]
# 2     [file_2.py:lines_10-20, file_2.py:lines_45-50]
# 3     [file_3.py:lines_10-20, file_3.py:lines_45-50]
# 4     [file_4.py:lines_10-20, file_4.py:lines_45-50]
# 5     [file_5.py:lines_10-20, file_5.py:lines_45-50]
# 6     [file_6.py:lines_10-20, file_6.py:lines_45-50]
# 7     [file_7.py:lines_10-20, file_7.py:lines_45-50]
# 8     [file_8.py:lines_10-20, file_8.py:lines_45-50]
# 9     [file_9.py:lines_10-20, file_9.py:lines_45-50]
# 10  [file_10.py:lines_10-20, file_10.py:lines_45-50]
# 11  [file_11.py:lines_10-20, file_11.py:lines_45-50]
# 12  [file_12.py:lines_10-20, file_12.py:lines_45-50]
# 13  [file_13.py:lines_10-20, file_13.py:lines_45-50]
# 14  [file_14.py:lines_10-20, file_14.py:lines_45-50]
# 15  [file_15.py:lines_10-20, file_15.py:lines_45-50]
# 16  [file_16.py:lines_10-20, file_16.py:lines_45-50]
# 17  [file_17.py:lines_10-20, file_17.py:lines_45-50]
# 18  [file_18.py:lines_10-20, file_18.py:lines_45-50]
# 19  [file_19.py:lines_10-20, file_19.py:lines_45-50]

# %%
df_llm_response
# Out:
#     nfr_id satisfaction_level  \
# 0    NFR_1             Denied
# 1    NFR_2                 NA
# 2    NFR_3             Denied
# 3    NFR_4                 NA
# 4    NFR_5                 NA
# 5    NFR_6   Weakly Satisfied
# 6    NFR_7          Satisfied
# 7    NFR_8      Weakly Denied
# 8    NFR_9             Denied
# 9   NFR_10                 NA
# 10  NFR_11             Denied
# 11  NFR_12      Weakly Denied
# 12  NFR_13                 NA
# 13  NFR_14   Weakly Satisfied
# 14  NFR_15             Denied
# 15  NFR_16   Weakly Satisfied
# 16  NFR_17             Denied
# 17  NFR_18             Denied
# 18  NFR_19          Satisfied
# 19  NFR_20             Denied
#
#                                        reasoning_text  \
# 0   Reasoning for NFR_1: The system uses encryptio...
# 1   Reasoning for NFR_2: The system uses encryptio...
# 2   Reasoning for NFR_3: The system uses encryptio...
# 3   Reasoning for NFR_4: The system uses encryptio...
# 4   Reasoning for NFR_5: The system uses encryptio...
# 5   Reasoning for NFR_6: Alternative explanation w...
# 6   Reasoning for NFR_7: The system uses encryptio...
# 7   Reasoning for NFR_8: The system uses encryptio...
# 8   Reasoning for NFR_9: Alternative explanation w...
# 9   Reasoning for NFR_10: The system uses encrypti...
# 10  Reasoning for NFR_11: The system uses encrypti...
# 11  Reasoning for NFR_12: Alternative explanation ...
# 12  Reasoning for NFR_13: Alternative explanation ...
# 13  Reasoning for NFR_14: The system uses encrypti...
# 14  Reasoning for NFR_15: The system uses encrypti...
# 15  Reasoning for NFR_16: The system uses encrypti...
# 16  Reasoning for NFR_17: The system uses encrypti...
# 17  Reasoning for NFR_18: The system uses encrypti...
# 18  Reasoning for NFR_19: The system uses encrypti...
# 19  Reasoning for NFR_20: The system uses encrypti...
#
#                                        code_locations
# 0      [file_0.py:lines_10-20, file_0.py:lines_45-50]
# 1      [file_1.py:lines_10-20, file_1.py:lines_45-50]
# 2   [file_2.py:lines_10-20, file_2_wrong.py:lines_...
# 3      [file_3.py:lines_10-20, file_3.py:lines_45-50]
# 4      [file_4.py:lines_10-20, file_4.py:lines_45-50]
# 5   [file_5.py:lines_10-20, file_5_wrong.py:lines_...
# 6      [file_6.py:lines_10-20, file_6.py:lines_45-50]
# 7      [file_7.py:lines_10-20, file_7.py:lines_45-50]
# 8      [file_8.py:lines_10-20, file_8.py:lines_45-50]
# 9      [file_9.py:lines_10-20, file_9.py:lines_45-50]
# 10  [file_10.py:lines_10-20, file_10_wrong.py:line...
# 11  [file_11.py:lines_10-20, file_11_wrong.py:line...
# 12   [file_12.py:lines_10-20, file_12.py:lines_45-50]
# 13   [file_13.py:lines_10-20, file_13.py:lines_45-50]
# 14  [file_14.py:lines_10-20, file_14_wrong.py:line...
# 15   [file_15.py:lines_10-20, file_15.py:lines_45-50]
# 16   [file_16.py:lines_10-20, file_16.py:lines_45-50]
# 17   [file_17.py:lines_10-20, file_17.py:lines_45-50]
# 18   [file_18.py:lines_10-20, file_18.py:lines_45-50]
# 19  [file_19.py:lines_10-20, file_19_wrong.py:line...

# %% [markdown]
# # MOCK Participants Data (for each participant-NFR)

# %%
participant_nfr_data = []
for participant_id in range(1, NUM_PARTICIPANTS + 1):    
    for nfr_idx in range(1, NUM_NFRS + 1):
        nfr_id = f'NFR_{nfr_idx}'
        agreement_options = ['Agree', 'Partially agree', 'Partially disagree', 'Disagree']
        
        llm_row = df_llm_response[df_llm_response['nfr_id'] == nfr_id].iloc[0]

        if np.random.random() < 0.8:
            participant_satisfaction_level = llm_row['satisfaction_level']
        else:
            alt_levels = [lvl for lvl in satisfaction_levels if lvl != llm_row['satisfaction_level']]
            participant_satisfaction_level = np.random.choice(alt_levels)

        if np.random.random() < 0.8:
            participant_reasoning_text = llm_row['reasoning_text']
        else:
            participant_reasoning_text = (
            f"Participant {participant_id} alternate reasoning for {nfr_id}: Different focus on usability and performance aspects.")

        if np.random.random() < 0.8:
            participant_code_locations = llm_row['code_locations']
        else:
            participant_code_locations = llm_row['code_locations'][:1] + [f"file_{nfr_idx}_participant.py:lines_60-70"]

        participant_nfr_data.append({
            'participant_id': participant_id,
            'nfr_id': nfr_id,
            'q1_satisfaction_agreement': np.random.choice(agreement_options, p=[0.5, 0.2, 0.2, 0.1]),
            'q2_reasoning_agreement': np.random.choice(agreement_options, p=[0.5, 0.25, 0.15, 0.1]),
            'q3_code_location_agreement': np.random.choice(agreement_options, p=[0.45, 0.25, 0.2, 0.1]),
            'participant_satisfaction_level': participant_satisfaction_level,
            'participant_reasoning_text': participant_reasoning_text,
            'participant_code_locations': participant_code_locations,
        })

df_participant_nfr = pd.DataFrame(participant_nfr_data)
df_participant_nfr
# Out:
#    participant_id nfr_id q1_satisfaction_agreement q2_reasoning_agreement  \
# 0               1  NFR_1           Partially agree        Partially agree
# 1               1  NFR_2        Partially disagree        Partially agree
# 2               1  NFR_3           Partially agree               Disagree
# 3               1  NFR_4           Partially agree               Disagree
# 4               1  NFR_5                     Agree                  Agree
#
#   q3_code_location_agreement participant_satisfaction_level  \
# 0                      Agree                         Denied
# 1                      Agree                             NA
# 2            Partially agree                         Denied
# 3                      Agree                             NA
# 4                      Agree               Weakly Satisfied
#
#                           participant_reasoning_text  \
# 0  Reasoning for NFR_1: The system uses encryptio...
# 1  Reasoning for NFR_2: The system uses encryptio...
# 2  Reasoning for NFR_3: The system uses encryptio...
# 3  Reasoning for NFR_4: The system uses encryptio...
# 4  Reasoning for NFR_5: The system uses encryptio...
#
#                           participant_code_locations
# 0     [file_0.py:lines_10-20, file_0.py:lines_45-50]
# 1     [file_1.py:lines_10-20, file_1.py:lines_45-50]
# 2  [file_2.py:lines_10-20, file_2_wrong.py:lines_...
# 3     [file_3.py:lines_10-20, file_3.py:lines_45-50]
# 4     [file_4.py:lines_10-20, file_4.py:lines_45-50]

# %%
df_participant_nfr
# Out:
#     participant_id  nfr_id q1_satisfaction_agreement q2_reasoning_agreement  \
# 0                1   NFR_1                     Agree                  Agree
# 1                1   NFR_2                     Agree        Partially agree
# 2                1   NFR_3        Partially disagree                  Agree
# 3                1   NFR_4                     Agree        Partially agree
# 4                1   NFR_5                     Agree     Partially disagree
# 5                1   NFR_6                  Disagree     Partially disagree
# 6                1   NFR_7        Partially disagree                  Agree
# 7                1   NFR_8           Partially agree                  Agree
# 8                1   NFR_9                     Agree        Partially agree
# 9                1  NFR_10           Partially agree                  Agree
# 10               1  NFR_11        Partially disagree                  Agree
# 11               1  NFR_12                     Agree                  Agree
# 12               1  NFR_13           Partially agree        Partially agree
# 13               1  NFR_14                     Agree               Disagree
# 14               1  NFR_15                     Agree                  Agree
# 15               1  NFR_16                     Agree        Partially agree
# 16               1  NFR_17                     Agree                  Agree
# 17               1  NFR_18                     Agree               Disagree
# 18               1  NFR_19           Partially agree     Partially disagree
# 19               1  NFR_20        Partially disagree                  Agree
# 20               2   NFR_1           Partially agree                  Agree
# 21               2   NFR_2           Partially agree        Partially agree
# 22               2   NFR_3                     Agree        Partially agree
# 23               2   NFR_4           Partially agree        Partially agree
# 24               2   NFR_5                  Disagree                  Agree
# 25               2   NFR_6                     Agree                  Agree
# 26               2   NFR_7                     Agree                  Agree
# 27               2   NFR_8           Partially agree        Partially agree
# 28               2   NFR_9                     Agree                  Agree
# 29               2  NFR_10                     Agree                  Agree
# 30               2  NFR_11                     Agree     Partially disagree
# 31               2  NFR_12                     Agree                  Agree
# 32               2  NFR_13                     Agree                  Agree
# 33               2  NFR_14           Partially agree                  Agree
# 34               2  NFR_15        Partially disagree     Partially disagree
# 35               2  NFR_16                     Agree     Partially disagree
# 36               2  NFR_17           Partially agree        Partially agree
# 37               2  NFR_18                     Agree     Partially disagree
# 38               2  NFR_19                  Disagree     Partially disagree
# 39               2  NFR_20                     Agree        Partially agree
#
#    q3_code_location_agreement participant_satisfaction_level  \
# 0                       Agree                         Denied
# 1                       Agree                             NA
# 2             Partially agree                  Weakly Denied
# 3                       Agree                             NA
# 4                       Agree                             NA
# 5             Partially agree               Weakly Satisfied
# 6                       Agree                             NA
# 7                       Agree                  Weakly Denied
# 8                       Agree                         Denied
# 9                       Agree                             NA
# 10                   Disagree                         Denied
# 11            Partially agree                  Weakly Denied
# 12                      Agree                             NA
# 13                      Agree               Weakly Satisfied
# 14            Partially agree                             NA
# 15                      Agree               Weakly Satisfied
# 16                      Agree                         Denied
# 17            Partially agree               Weakly Satisfied
# 18                      Agree                      Satisfied
# 19         Partially disagree                         Denied
# 20                      Agree                      Satisfied
# 21            Partially agree                             NA
# 22            Partially agree                         Denied
# 23                      Agree                      Satisfied
# 24                      Agree                             NA
# 25            Partially agree               Weakly Satisfied
# 26         Partially disagree                      Satisfied
# 27                   Disagree                  Weakly Denied
# 28                      Agree                         Denied
# 29            Partially agree                             NA
# 30                      Agree                         Denied
# 31            Partially agree                  Weakly Denied
# 32                      Agree                             NA
# 33            Partially agree               Weakly Satisfied
# 34                      Agree                         Denied
# 35                      Agree               Weakly Satisfied
# 36            Partially agree                  Weakly Denied
# 37                      Agree                         Denied
# 38            Partially agree                      Satisfied
# 39         Partially disagree                         Denied
#
#                            participant_reasoning_text  \
# 0   Participant 1 alternate reasoning for NFR_1: D...
# 1   Reasoning for NFR_2: The system uses encryptio...
# 2   Reasoning for NFR_3: The system uses encryptio...
# 3   Reasoning for NFR_4: The system uses encryptio...
# 4   Participant 1 alternate reasoning for NFR_5: D...
# 5   Reasoning for NFR_6: Alternative explanation w...
# 6   Reasoning for NFR_7: The system uses encryptio...
# 7   Participant 1 alternate reasoning for NFR_8: D...
# 8   Reasoning for NFR_9: Alternative explanation w...
# 9   Reasoning for NFR_10: The system uses encrypti...
# 10  Reasoning for NFR_11: The system uses encrypti...
# 11  Participant 1 alternate reasoning for NFR_12: ...
# 12  Reasoning for NFR_13: Alternative explanation ...
# 13  Reasoning for NFR_14: The system uses encrypti...
# 14  Participant 1 alternate reasoning for NFR_15: ...
# 15  Reasoning for NFR_16: The system uses encrypti...
# 16  Reasoning for NFR_17: The system uses encrypti...
# 17  Reasoning for NFR_18: The system uses encrypti...
# 18  Participant 1 alternate reasoning for NFR_19: ...
# 19  Reasoning for NFR_20: The system uses encrypti...
# 20  Reasoning for NFR_1: The system uses encryptio...
# 21  Reasoning for NFR_2: The system uses encryptio...
# 22  Reasoning for NFR_3: The system uses encryptio...
# 23  Reasoning for NFR_4: The system uses encryptio...
# 24  Participant 2 alternate reasoning for NFR_5: D...
# 25  Reasoning for NFR_6: Alternative explanation w...
# 26  Reasoning for NFR_7: The system uses encryptio...
# 27  Participant 2 alternate reasoning for NFR_8: D...
# 28  Reasoning for NFR_9: Alternative explanation w...
# 29  Participant 2 alternate reasoning for NFR_10: ...
# 30  Reasoning for NFR_11: The system uses encrypti...
# 31  Reasoning for NFR_12: Alternative explanation ...
# 32  Reasoning for NFR_13: Alternative explanation ...
# 33  Participant 2 alternate reasoning for NFR_14: ...
# 34  Reasoning for NFR_15: The system uses encrypti...
# 35  Reasoning for NFR_16: The system uses encrypti...
# 36  Reasoning for NFR_17: The system uses encrypti...
# 37  Participant 2 alternate reasoning for NFR_18: ...
# 38  Reasoning for NFR_19: The system uses encrypti...
# 39  Reasoning for NFR_20: The system uses encrypti...
#
#                            participant_code_locations
# 0   [file_0.py:lines_10-20, file_1_participant.py:...
# 1      [file_1.py:lines_10-20, file_1.py:lines_45-50]
# 2   [file_2.py:lines_10-20, file_2_wrong.py:lines_...
# 3      [file_3.py:lines_10-20, file_3.py:lines_45-50]
# 4      [file_4.py:lines_10-20, file_4.py:lines_45-50]
# 5   [file_5.py:lines_10-20, file_5_wrong.py:lines_...
# 6      [file_6.py:lines_10-20, file_6.py:lines_45-50]
# 7      [file_7.py:lines_10-20, file_7.py:lines_45-50]
# 8      [file_8.py:lines_10-20, file_8.py:lines_45-50]
# 9      [file_9.py:lines_10-20, file_9.py:lines_45-50]
# 10  [file_10.py:lines_10-20, file_10_wrong.py:line...
# 11  [file_11.py:lines_10-20, file_11_wrong.py:line...
# 12   [file_12.py:lines_10-20, file_12.py:lines_45-50]
# 13  [file_13.py:lines_10-20, file_14_participant.p...
# 14  [file_14.py:lines_10-20, file_14_wrong.py:line...
# 15   [file_15.py:lines_10-20, file_15.py:lines_45-50]
# 16  [file_16.py:lines_10-20, file_17_participant.p...
# 17   [file_17.py:lines_10-20, file_17.py:lines_45-50]
# 18  [file_18.py:lines_10-20, file_19_participant.p...
# 19  [file_19.py:lines_10-20, file_20_participant.p...
# 20  [file_0.py:lines_10-20, file_1_participant.py:...
# 21     [file_1.py:lines_10-20, file_1.py:lines_45-50]
# 22  [file_2.py:lines_10-20, file_2_wrong.py:lines_...
# 23     [file_3.py:lines_10-20, file_3.py:lines_45-50]
# 24     [file_4.py:lines_10-20, file_4.py:lines_45-50]
# 25  [file_5.py:lines_10-20, file_6_participant.py:...
# 26  [file_6.py:lines_10-20, file_7_participant.py:...
# 27     [file_7.py:lines_10-20, file_7.py:lines_45-50]
# 28     [file_8.py:lines_10-20, file_8.py:lines_45-50]
# 29  [file_9.py:lines_10-20, file_10_participant.py...
# 30  [file_10.py:lines_10-20, file_10_wrong.py:line...
# 31  [file_11.py:lines_10-20, file_11_wrong.py:line...
# 32   [file_12.py:lines_10-20, file_12.py:lines_45-50]
# 33   [file_13.py:lines_10-20, file_13.py:lines_45-50]
# 34  [file_14.py:lines_10-20, file_15_participant.p...
# 35   [file_15.py:lines_10-20, file_15.py:lines_45-50]
# 36   [file_16.py:lines_10-20, file_16.py:lines_45-50]
# 37   [file_17.py:lines_10-20, file_17.py:lines_45-50]
# 38   [file_18.py:lines_10-20, file_18.py:lines_45-50]
# 39  [file_19.py:lines_10-20, file_19_wrong.py:line...

# %% [markdown]
# # RQ1 ANALYSIS: Assessment Accuracy

# %%
def calculate_code_location_metrics(gt_locations, llm_locations):
    """
    Calculate Precision, Recall, and F1 for code locations.
    Treats locations as sets and computes overlap.
    """
    gt_set = set(gt_locations)
    llm_set = set(llm_locations)
    
    if len(llm_set) == 0:
        precision = 0.0
    else:
        precision = len(gt_set.intersection(llm_set)) / len(llm_set)
    
    if len(gt_set) == 0:
        recall = 0.0
    else:
        recall = len(gt_set.intersection(llm_set)) / len(gt_set)
    
    if precision + recall == 0:
        f1 = 0.0
    else:
        f1 = 2 * (precision * recall) / (precision + recall)
    
    return precision, recall, f1

print("=" * 80)
print("RQ1: ASSESSMENT ACCURACY ANALYSIS")
print("=" * 80)

# Merge ground truth and LLM responses for comparison
df_comparison = df_ground_truth.merge(
    df_llm_response, 
    on='nfr_id', 
    suffixes=('_gt', '_llm')
)
# Out:
# ================================================================================
# RQ1: ASSESSMENT ACCURACY ANALYSIS
# ================================================================================

# %%
df_comparison
# Out:
#     nfr_id satisfaction_level_gt  \
# 0    NFR_1                Denied
# 1    NFR_2                    NA
# 2    NFR_3         Weakly Denied
# 3    NFR_4                    NA
# 4    NFR_5                    NA
# 5    NFR_6      Weakly Satisfied
# 6    NFR_7         Weakly Denied
# 7    NFR_8         Weakly Denied
# 8    NFR_9         Weakly Denied
# 9   NFR_10                    NA
# 10  NFR_11                Denied
# 11  NFR_12         Weakly Denied
# 12  NFR_13                    NA
# 13  NFR_14      Weakly Satisfied
# 14  NFR_15                Denied
# 15  NFR_16      Weakly Satisfied
# 16  NFR_17                Denied
# 17  NFR_18                    NA
# 18  NFR_19             Satisfied
# 19  NFR_20                Denied
#
#                                     reasoning_text_gt  \
# 0   Reasoning for NFR_1: The system uses encryptio...
# 1   Reasoning for NFR_2: The system uses encryptio...
# 2   Reasoning for NFR_3: The system uses encryptio...
# 3   Reasoning for NFR_4: The system uses encryptio...
# 4   Reasoning for NFR_5: The system uses encryptio...
# 5   Reasoning for NFR_6: The system uses encryptio...
# 6   Reasoning for NFR_7: The system uses encryptio...
# 7   Reasoning for NFR_8: The system uses encryptio...
# 8   Reasoning for NFR_9: The system uses encryptio...
# 9   Reasoning for NFR_10: The system uses encrypti...
# 10  Reasoning for NFR_11: The system uses encrypti...
# 11  Reasoning for NFR_12: The system uses encrypti...
# 12  Reasoning for NFR_13: The system uses encrypti...
# 13  Reasoning for NFR_14: The system uses encrypti...
# 14  Reasoning for NFR_15: The system uses encrypti...
# 15  Reasoning for NFR_16: The system uses encrypti...
# 16  Reasoning for NFR_17: The system uses encrypti...
# 17  Reasoning for NFR_18: The system uses encrypti...
# 18  Reasoning for NFR_19: The system uses encrypti...
# 19  Reasoning for NFR_20: The system uses encrypti...
#
#                                    code_locations_gt satisfaction_level_llm  \
# 0     [file_0.py:lines_10-20, file_0.py:lines_45-50]                 Denied
# 1     [file_1.py:lines_10-20, file_1.py:lines_45-50]                     NA
# 2     [file_2.py:lines_10-20, file_2.py:lines_45-50]                 Denied
# 3     [file_3.py:lines_10-20, file_3.py:lines_45-50]                     NA
# 4     [file_4.py:lines_10-20, file_4.py:lines_45-50]                     NA
# 5     [file_5.py:lines_10-20, file_5.py:lines_45-50]       Weakly Satisfied
# 6     [file_6.py:lines_10-20, file_6.py:lines_45-50]              Satisfied
# 7     [file_7.py:lines_10-20, file_7.py:lines_45-50]          Weakly Denied
# 8     [file_8.py:lines_10-20, file_8.py:lines_45-50]                 Denied
# 9     [file_9.py:lines_10-20, file_9.py:lines_45-50]                     NA
# 10  [file_10.py:lines_10-20, file_10.py:lines_45-50]                 Denied
# 11  [file_11.py:lines_10-20, file_11.py:lines_45-50]          Weakly Denied
# 12  [file_12.py:lines_10-20, file_12.py:lines_45-50]                     NA
# 13  [file_13.py:lines_10-20, file_13.py:lines_45-50]       Weakly Satisfied
# 14  [file_14.py:lines_10-20, file_14.py:lines_45-50]                 Denied
# 15  [file_15.py:lines_10-20, file_15.py:lines_45-50]       Weakly Satisfied
# 16  [file_16.py:lines_10-20, file_16.py:lines_45-50]                 Denied
# 17  [file_17.py:lines_10-20, file_17.py:lines_45-50]                 Denied
# 18  [file_18.py:lines_10-20, file_18.py:lines_45-50]              Satisfied
# 19  [file_19.py:lines_10-20, file_19.py:lines_45-50]                 Denied
#
#                                    reasoning_text_llm  \
# 0   Reasoning for NFR_1: The system uses encryptio...
# 1   Reasoning for NFR_2: The system uses encryptio...
# 2   Reasoning for NFR_3: The system uses encryptio...
# 3   Reasoning for NFR_4: The system uses encryptio...
# 4   Reasoning for NFR_5: The system uses encryptio...
# 5   Reasoning for NFR_6: Alternative explanation w...
# 6   Reasoning for NFR_7: The system uses encryptio...
# 7   Reasoning for NFR_8: The system uses encryptio...
# 8   Reasoning for NFR_9: Alternative explanation w...
# 9   Reasoning for NFR_10: The system uses encrypti...
# 10  Reasoning for NFR_11: The system uses encrypti...
# 11  Reasoning for NFR_12: Alternative explanation ...
# 12  Reasoning for NFR_13: Alternative explanation ...
# 13  Reasoning for NFR_14: The system uses encrypti...
# 14  Reasoning for NFR_15: The system uses encrypti...
# 15  Reasoning for NFR_16: The system uses encrypti...
# 16  Reasoning for NFR_17: The system uses encrypti...
# 17  Reasoning for NFR_18: The system uses encrypti...
# 18  Reasoning for NFR_19: The system uses encrypti...
# 19  Reasoning for NFR_20: The system uses encrypti...
#
#                                    code_locations_llm
# 0      [file_0.py:lines_10-20, file_0.py:lines_45-50]
# 1      [file_1.py:lines_10-20, file_1.py:lines_45-50]
# 2   [file_2.py:lines_10-20, file_2_wrong.py:lines_...
# 3      [file_3.py:lines_10-20, file_3.py:lines_45-50]
# 4      [file_4.py:lines_10-20, file_4.py:lines_45-50]
# 5   [file_5.py:lines_10-20, file_5_wrong.py:lines_...
# 6      [file_6.py:lines_10-20, file_6.py:lines_45-50]
# 7      [file_7.py:lines_10-20, file_7.py:lines_45-50]
# 8      [file_8.py:lines_10-20, file_8.py:lines_45-50]
# 9      [file_9.py:lines_10-20, file_9.py:lines_45-50]
# 10  [file_10.py:lines_10-20, file_10_wrong.py:line...
# 11  [file_11.py:lines_10-20, file_11_wrong.py:line...
# 12   [file_12.py:lines_10-20, file_12.py:lines_45-50]
# 13   [file_13.py:lines_10-20, file_13.py:lines_45-50]
# 14  [file_14.py:lines_10-20, file_14_wrong.py:line...
# 15   [file_15.py:lines_10-20, file_15.py:lines_45-50]
# 16   [file_16.py:lines_10-20, file_16.py:lines_45-50]
# 17   [file_17.py:lines_10-20, file_17.py:lines_45-50]
# 18   [file_18.py:lines_10-20, file_18.py:lines_45-50]
# 19  [file_19.py:lines_10-20, file_19_wrong.py:line...

# %% [markdown]
# https://www.baeldung.com/cs/multi-class-f1-score
#
# https://towardsdatascience.com/micro-macro-weighted-averages-of-f1-score-clearly-explained-b603420b292f/

# %%
print("SATISFACTION LEVEL ASSESSMENT")

satisfaction_matches = (df_comparison['satisfaction_level_gt'] == df_comparison['satisfaction_level_llm']).sum()
satisfaction_accuracy = satisfaction_matches / len(df_comparison)

print(f"\nAccuracy: {satisfaction_accuracy:.1%} ({satisfaction_matches}/{len(df_comparison)})")

from sklearn.metrics import f1_score

macro_f1_satisfaction = f1_score(
    df_comparison['satisfaction_level_gt'],
    df_comparison['satisfaction_level_llm'],
    average='macro'
)

print(f"Macro-F1 Score: {macro_f1_satisfaction:.3f}")

kappa_satisfaction = cohen_kappa_score(
    df_comparison['satisfaction_level_gt'],
    df_comparison['satisfaction_level_llm']
)

print(f"Cohen's Kappa: {kappa_satisfaction:.3f}")
# Out:
# SATISFACTION LEVEL ASSESSMENT
#
# Accuracy: 80.0% (16/20)
# Macro-F1 Score: 0.783
# Cohen's Kappa: 0.741

# %%
satisfaction_agreement = df_participant_nfr['q1_satisfaction_agreement'].value_counts()
total_assessments = len(df_participant_nfr)

print(f"\nParticipant Agreement Distribution:")
for option in ['Agree', 'Partially agree', 'Partially disagree', 'Disagree']:
    count = satisfaction_agreement.get(option, 0)
    percentage = (count / total_assessments) * 100
    print(f"  {option:20s}: {count:3d} ({percentage:5.1f}%)")

agree_count = 5 * satisfaction_agreement.get('Agree', 0) + 4 * satisfaction_agreement.get('Partially agree', 0) + 2 * satisfaction_agreement.get('Partially disagree', 0) + 1 * satisfaction_agreement.get('Disagree', 0)
agreement_rate = agree_count / total_assessments
print(f"\nOverall Agreement Rate: {agreement_rate}")

# Inter-rater reliability among participants
participants = df_participant_nfr['participant_id'].unique()[:2]
ratings_p1 = df_participant_nfr[df_participant_nfr['participant_id'] == participants[0]][['nfr_id', 'q1_satisfaction_agreement']]
ratings_p2 = df_participant_nfr[df_participant_nfr['participant_id'] == participants[1]][['nfr_id', 'q1_satisfaction_agreement']]

common = ratings_p1.merge(ratings_p2, on='nfr_id', suffixes=('_p1', '_p2'))

alpha_satisfaction = cohen_kappa_score(
    common['q1_satisfaction_agreement_p1'],
    common['q1_satisfaction_agreement_p2']
) if not common.empty else np.nan
print(f"Cohen's Kappa (participants {participants[0]} vs {participants[1]}): {alpha_satisfaction:.3f}")
# Out:
# Participant Agreement Distribution:
#   Agree               :  22 ( 55.0%)
#   Partially agree     :  10 ( 25.0%)
#   Partially disagree  :   5 ( 12.5%)
#   Disagree            :   3 (  7.5%)
#
# Overall Agreement Rate: 4.075
# Cohen's Kappa (participants 1 vs 2): -0.205

# %% [markdown]
# # RQ1 ANALYSIS: Reasoning Accuracy

# %%
# BLEU-like unigram precision for reasoning text
def simple_unigram_bleu(ref, hyp):
    ref_tokens = ref.lower().split()
    hyp_tokens = hyp.lower().split()
    if not hyp_tokens:
        return 0.0
    overlap = sum(min(ref_tokens.count(tok), hyp_tokens.count(tok)) for tok in set(hyp_tokens))
    return overlap / len(hyp_tokens)

bleu_scores = df_comparison.apply(
    lambda row: simple_unigram_bleu(row['reasoning_text_gt'], row['reasoning_text_llm']),
    axis=1
)
print(f"Average BLEU-like score (reasoning): {bleu_scores.mean():.3f}")

# semantic similarity
def calculate_semantic_similarity(text1, text2):
    """
    Simulate semantic similarity calculation.
    In practice, this would use BERT embeddings or similar.
    """
    if text1 == text2:
        return np.random.uniform(0.90, 1.0)
    else:       
        return np.random.uniform(0.60, 0.85)

reasoning_similarities = df_comparison.apply(
    lambda row: calculate_semantic_similarity(row['reasoning_text_gt'], row['reasoning_text_llm']),
    axis=1
)
print(f"Average semantic similarity (reasoning): {reasoning_similarities.mean():.3f}")

# f1 score
# Out:
# Average BLEU-like score (reasoning): 0.875
# Average semantic similarity (reasoning): 0.893

# %% [markdown]
# # User Satisfaction Survey Data (RQ2)
