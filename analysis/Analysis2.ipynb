# %%
import json

# Load demographic.json
with open('../data/5.all-data/demographics.json', 'r') as f:
    demographic = json.load(f)
print('demographics.json:', 'demographic', 'len =', len(demographic))

# Load satisfaction_survey.json
with open('../data/5.all-data/satisfaction_survey.json', 'r') as f:
    satisfaction = json.load(f)
print('satisfaction_survey.json:', 'satisfaction', 'len =', len(satisfaction))


# Load conversation.json
with open('../data/8.annotated_data/conversations.json', 'r') as f:
    conversation = json.load(f)
print('conversation.json:', 'conversation', 'len =', len(conversation))

# Load nfr_responses.json
with open('../data/8.annotated_data/nfr_responses.json', 'r') as f:
    nfr_response = json.load(f)
print('nfr_responses.json:', 'nfr_response', 'len =', len(nfr_response))


GT = {}
with open("../GT/GT_resolved.json", "r", encoding="utf-8") as f:
    for responses in json.load(f):
        for r in responses:
            GT[r['id']] = r


pilot_uni = [
    "e7c3d057-f0bb-4f30-aea0-ab689f9412ac",
    "18d5b4e7-f5c2-4dd3-81d8-6f21ecc1962b",
    "2d83f401-5153-45ed-9078-1c31e035849a",
    "368b58b7-feed-445b-a0ab-0e0b2b65dc5a",
]
pilot_prolific = [
    "e6991c2e-926c-4445-aae9-10a75496945f",
    "b50b6c66-2252-47cf-a890-9f13757be68c",
    "78288bfa-e19e-4af8-acad-effa1e3aae35",
    "700f34fb-b376-44ef-98c3-a55a045abdd5",
]
study_prolific = [
    "7fe17f91-130a-4c4f-a0b8-443278009213",
"f9399963-3f69-43d2-8d9d-e0a573a9c35d",
"3292c831-2fc7-4a52-81c9-7aa63cac86e8",
"e4691f7a-773b-438b-a7db-fd4cb12dc37f",
"397d6632-4575-4fb1-bbe4-b752e201a4bd",
"4274f797-dc8b-4127-bb50-bcf5c4a2e2bd",
"b4b276ed-55d1-4874-b61c-e47d9075125a",
"e9d46a67-49a6-445b-a851-46effd7e101c",
"0bd8d561-486c-45e5-8722-7048d22ce8e5",
"9a5f8d45-6bf0-4f1e-aadb-9011d213e24b",
"456bc583-cfbd-43c6-848c-f85006ad6e1f",
"c497b8f4-f74e-4979-9670-3fc496e09200",
"b2edd4e6-9b8f-43f4-bda5-77d43bcffc7e",
"1540a642-a495-4b83-ae3c-937a1aedf6ea",
"58d21f9f-8845-4f48-a523-6a85d220837d",
"996a0e8f-2294-4183-a4a2-c29e88930d65",
"4f99cde7-92af-4b5f-afcc-db146c3bba01",
"63f8d518-54ca-43aa-8a2f-68a165144b07",
"22438425-5563-4e62-929f-ed03b21ef583",
"13ce0d0c-67e9-422c-ac96-757d5bd3b837",
"99234c2d-5838-4f45-9a84-1eef505b4126",
"a85fbaef-eff6-4d7d-93d1-1017b8107bdc",
"3839c20d-a24f-49b8-b1a3-20f6eecac866",
"f384d13f-c84b-4163-a343-a035dbf5374f",
"04ac4c73-369b-4f7e-b5a7-a80597e93626",
"d05a5c3a-ab44-45b2-9437-b2698d86f52f",
"7ff75834-6394-4c93-9c99-b8859c5dbd7d",
"7958d91f-2dc8-4d9f-9bf0-6ea33fa3f927",
"bd165a59-c41e-4f93-9eaa-b34e19f4b7f6",
"977831a4-7811-4832-a8ed-fd4d830aaf18",
"71013647-e3d1-498e-afc3-ec1f4252cab7",
"b07644cc-9eda-4e68-b848-126831f7ad67",
"12c1fce4-4274-4df0-a964-427498920d15",
"f5c2ee02-60ba-4601-8659-ce3c65110b53",
"d4b12d74-82bd-4586-a6fd-5e701da1d253",
"e58ecbc0-6eda-433a-b765-b4d27976946c",
"25321c1d-2b9d-4762-877d-2b3f6d550a7d",
"1931388e-490b-478b-bb81-a66de854fea8",
"0133784d-c032-4518-97c6-b6b58fe671aa",
"d9675153-b7e3-47ed-98b0-f33fdc21456d",
"5ab35d1c-d7d0-422d-acb0-56e5c43b6817",
]

print('pilot_uni len =', len(pilot_uni))
print('pilot_prolific len =', len(pilot_prolific))
print('study_prolific len =', len(study_prolific))

# Assert no overlap between lists
assert not (set(pilot_uni) & set(pilot_prolific)), "pilot_uni and pilot_prolific have overlap!"
assert not (set(pilot_uni) & set(study_prolific)), "pilot_uni and study_prolific have overlap!"
assert not (set(pilot_prolific) & set(study_prolific)), "pilot_prolific and study_prolific have overlap!"
print('No overlap between pilot_uni, pilot_prolific, and study_prolific.')
# Out:
# demographics.json: demographic len = 49
# satisfaction_survey.json: satisfaction len = 49
# conversation.json: conversation len = 34
# nfr_responses.json: nfr_response len = 34
# pilot_uni len = 4
# pilot_prolific len = 4
# study_prolific len = 41
# No overlap between pilot_uni, pilot_prolific, and study_prolific.

# %% [markdown]
# satisfaction level

# %%
y_true = []
y_pred = []
satisfavtion_levels = ["satisfied", "weakly satisfied", "weakly denied", "denied"]
for pid, responses in nfr_response.items():
    for response in responses:
        if response.get("is_attention_question", False):
            continue
        id = response['nfr_id']
        y1 = response["satisfaction_level"].lower()
        y2 = GT[id]["satisfaction_level"].lower()
        if y2 not in satisfavtion_levels:
            raise Exception(f'error {id} GT')
        if y1 not in satisfavtion_levels:
            raise Exception(f'error {id} {pid}')
        y_true.append(y2)
        y_pred.append(y1)

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

precision = precision_score(y_true, y_pred, average="macro")
recall = recall_score(y_true, y_pred, average="macro")
f1 = f1_score(y_true, y_pred, average="macro")

print(f"Macro Precision: {precision:.3f}")
print(f"Macro Recall:    {recall:.3f}")
print(f"Macro F1 Score:  {f1:.3f}")
# Out:
# {'weakly satisfied', 'denied', 'weakly denied', 'satisfied'}
# {'weakly satisfied', 'denied', 'weakly denied', 'satisfied'}
# Macro Precision: 0.438
# Macro Recall:    0.418
# Macro F1 Score:  0.381

# %% [markdown]
# reasoning

# %%
# pip install bert-score
# pip install transformers
# https://haticeozbolat17.medium.com/text-summarization-how-to-calculate-bertscore-771a51022964
#from transformers import BertTokenizer, BertForMaskedLM, BertModel
from transformers import BertTokenizer, BertForMaskedLM, BertModel
from bert_score import BERTScorer
import torch
import numpy as np

# Example texts
reference = "This is a reference text example."
candidate = "This is a candidate text example."
# BERTScore calculation
scorer = BERTScorer(model_type='bert-base-uncased')

def get_bert_score(reference, candidate):
    P, R, F1 = scorer.score([candidate], [reference])
    return P, R, F1

P, R, F1 = get_bert_score(reference, candidate)
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

def get_bert_cosine_sim(text1, text2):
    inputs1 = tokenizer(text1, return_tensors="pt", padding=True, truncation=True)
    inputs2 = tokenizer(text2, return_tensors="pt", padding=True, truncation=True)
    outputs1 = model(**inputs1)
    outputs2 = model(**inputs2)
    embeddings1 = outputs1.last_hidden_state.mean(dim=1).detach().numpy()
    embeddings2 = outputs2.last_hidden_state.mean(dim=1).detach().numpy()
    similarity = np.dot(embeddings1, embeddings2.T) / (np.linalg.norm(embeddings1) * np.linalg.norm(embeddings2))
    return similarity

text1 = "This is an example text."
text2 = "This text contains an example sentence."
similarity = get_bert_cosine_sim(text1, text2)
print("Similarity between the texts: {:.4f}".format(similarity[0][0]))
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 1549.28it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# BERTScore Precision: 0.9258, Recall: 0.9258, F1: 0.9258
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 1559.18it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Similarity between the texts: 0.9000

# %%
y_p = []
y_r = []
y_f = []
y_s = []
reasonings = []

for pid, responses in nfr_response.items():
    for response in responses:
        if response.get("is_attention_question", False):
            continue
        id = response['nfr_id']
        y1 = response["reasoning"]
        y2 = GT[id]["reasoning"]
        P, R, F1 = get_bert_score(y1, y2)
        similarity = get_bert_cosine_sim(y1, y2)
        y_p.append(P.item())
        y_r.append(R.item())
        y_f.append(F1.item())
        y_s.append(similarity)
        reasonings.append((y1, y2))


print(f"BERTScore F1: {np.mean(y_f):.4f} ± {np.std(y_f):.4f}")
print(f"BERTScore P:  {np.mean(y_p):.4f} ± {np.std(y_p):.4f}")
print(f"BERTScore R:  {np.mean(y_r):.4f} ± {np.std(y_r):.4f}")
print(f"Cosine Sim:   {np.mean(y_s):.4f} ± {np.std(y_s):.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 14
#      12 y1 = response["reasoning"]
#      13 y2 = GT[id]["reasoning"]
# ---> 14 P, R, F1 = get_bert_score(y1, y2)
#      15 similarity = get_bert_cosine_sim(y1, y2)
#      16 y_p.append(P.item())
#
# Cell In[30], line 17, in get_bert_score(reference, candidate)
#      16 def get_bert_score(reference, candidate):
# ---> 17     P, R, F1 = scorer.score([candidate], [reference])
#      18     return P, R, F1
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/bert_score/scorer.py:220, in BERTScorer.score(self, cands, refs, verbose, batch_size, return_hash)
#     217     idf_dict[self._tokenizer.sep_token_id] = 0
#     218     idf_dict[self._tokenizer.cls_token_id] = 0
# --> 220 all_preds = bert_cos_score_idf(
#     221     self._model,
#     222     refs,
#     223     cands,
#     224     self._tokenizer,
#     225     idf_dict,
#     226     verbose=verbose,
#     227     device=self.device,
#     228     batch_size=batch_size,
#     229     all_layers=self.all_layers,
#     230 ).cpu()
#     232 if ref_group_boundaries is not None:
#     233     max_preds = []
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/bert_score/utils.py:616, in bert_cos_score_idf(model, refs, hyps, tokenizer, idf_dict, verbose, batch_size, device, all_layers)
#     614 for batch_start in iter_range:
#     615     sen_batch = sentences[batch_start : batch_start + batch_size]
# --> 616     embs, masks, padded_idf = get_bert_embedding(
#     617         sen_batch, model, tokenizer, idf_dict, device=device, all_layers=all_layers
#     618     )
#     619     embs = embs.cpu()
#     620     masks = masks.cpu()
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/bert_score/utils.py:455, in get_bert_embedding(all_sens, model, tokenizer, idf_dict, batch_size, device, all_layers)
#     453 with torch.no_grad():
#     454     for i in range(0, len(all_sens), batch_size):
# --> 455         batch_embedding = bert_encode(
#     456             model,
#     457             padded_sens[i : i + batch_size],
#     458             attention_mask=mask[i : i + batch_size],
#     459             all_layers=all_layers,
#     460         )
#     461         embeddings.append(batch_embedding)
#     462         del batch_embedding
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/bert_score/utils.py:351, in bert_encode(model, x, attention_mask, all_layers)
#     349 model.eval()
#     350 with torch.no_grad():
# --> 351     out = model(x, attention_mask=attention_mask, output_hidden_states=all_layers)
#     352 if all_layers:
#     353     emb = torch.stack(out[-1], dim=2)
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/utils/generic.py:1001, in check_model_inputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     999             outputs = func(self, *args, **kwargs)
#    1000     else:
# -> 1001         outputs = func(self, *args, **kwargs)
#    1002 except TypeError as original_exception:
#    1003     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1004     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1005     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1006     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:696, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     679 embedding_output = self.embeddings(
#     680     input_ids=input_ids,
#     681     position_ids=position_ids,
#    (...)
#     684     past_key_values_length=past_key_values_length,
#     685 )
#     687 attention_mask, encoder_attention_mask = self._create_attention_masks(
#     688     attention_mask=attention_mask,
#     689     encoder_attention_mask=encoder_attention_mask,
#    (...)
#     693     past_key_values=past_key_values,
#     694 )
# --> 696 encoder_outputs = self.encoder(
#     697     embedding_output,
#     698     attention_mask=attention_mask,
#     699     encoder_hidden_states=encoder_hidden_states,
#     700     encoder_attention_mask=encoder_attention_mask,
#     701     past_key_values=past_key_values,
#     702     use_cache=use_cache,
#     703     cache_position=cache_position,
#     704     position_ids=position_ids,
#     705     **kwargs,
#     706 )
#     707 sequence_output = encoder_outputs.last_hidden_state
#     708 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:452, in BertEncoder.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     440 def forward(
#     441     self,
#     442     hidden_states: torch.Tensor,
#    (...)
#     449     **kwargs: Unpack[TransformersKwargs],
#     450 ) -> tuple[torch.Tensor] | BaseModelOutputWithPastAndCrossAttentions:
#     451     for i, layer_module in enumerate(self.layer):
# --> 452         hidden_states = layer_module(
#     453             hidden_states,
#     454             attention_mask,
#     455             encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     456             encoder_attention_mask=encoder_attention_mask,
#     457             past_key_values=past_key_values,
#     458             cache_position=cache_position,
#     459             **kwargs,
#     460         )
#     462     return BaseModelOutputWithPastAndCrossAttentions(
#     463         last_hidden_state=hidden_states,
#     464         past_key_values=past_key_values if use_cache else None,
#     465     )
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:397, in BertLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     387 def forward(
#     388     self,
#     389     hidden_states: torch.Tensor,
#    (...)
#     395     **kwargs: Unpack[TransformersKwargs],
#     396 ) -> tuple[torch.Tensor]:
# --> 397     self_attention_output, _ = self.attention(
#     398         hidden_states,
#     399         attention_mask,
#     400         past_key_values=past_key_values,
#     401         cache_position=cache_position,
#     402         **kwargs,
#     403     )
#     404     attention_output = self_attention_output
#     406     if self.is_decoder and encoder_hidden_states is not None:
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:326, in BertAttention.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     315 def forward(
#     316     self,
#     317     hidden_states: torch.Tensor,
#    (...)
#     323     **kwargs: Unpack[TransformersKwargs],
#     324 ) -> tuple[torch.Tensor]:
#     325     attention_mask = attention_mask if not self.is_cross_attention else encoder_attention_mask
# --> 326     attention_output, attn_weights = self.self(
#     327         hidden_states,
#     328         encoder_hidden_states=encoder_hidden_states,
#     329         attention_mask=attention_mask,
#     330         past_key_values=past_key_values,
#     331         cache_position=cache_position,
#     332         **kwargs,
#     333     )
#     334     attention_output = self.output(attention_output, hidden_states)
#     335     return attention_output, attn_weights
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:202, in BertSelfAttention.forward(self, hidden_states, attention_mask, past_key_values, cache_position, **kwargs)
#     191     key_layer, value_layer = current_past_key_values.update(
#     192         key_layer,
#     193         value_layer,
#     194         self.layer_idx,
#     195         {"cache_position": cache_position},
#     196     )
#     198 attention_interface: Callable = ALL_ATTENTION_FUNCTIONS.get_interface(
#     199     self.config._attn_implementation, eager_attention_forward
#     200 )
# --> 202 attn_output, attn_weights = attention_interface(
#     203     self,
#     204     query_layer,
#     205     key_layer,
#     206     value_layer,
#     207     attention_mask,
#     208     dropout=0.0 if not self.training else self.dropout.p,
#     209     scaling=self.scaling,
#     210     **kwargs,
#     211 )
#     212 attn_output = attn_output.reshape(*input_shape, -1).contiguous()
#     213 return attn_output, attn_weights
#
# File /opt/miniconda3/envs/dialogue/lib/python3.10/site-packages/transformers/integrations/sdpa_attention.py:92, in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, **kwargs)
#      88     if attention_mask is not None and attention_mask.dtype != torch.bool:
#      89         # Convert to boolean type, making sdpa to force call FlashAttentionScore to improve performance.
#      90         attention_mask = torch.logical_not(attention_mask.bool()).to(query.device)
# ---> 92 attn_output = torch.nn.functional.scaled_dot_product_attention(
#      93     query,
#      94     key,
#      95     value,
#      96     attn_mask=attention_mask,
#      97     dropout_p=dropout,
#      98     scale=scaling,
#      99     is_causal=is_causal,
#     100     **sdpa_kwargs,
#     101 )
#     102 attn_output = attn_output.transpose(1, 2).contiguous()
#     104 return attn_output, None
#
# KeyboardInterrupt:

# %%
import numpy as np

max_idx = np.argmax(y_s)
min_idx = np.argmin(y_s)


print("Highest similarity:")
print(y_s[max_idx])
print("y1:", reasonings[max_idx][0])
print("y2:", reasonings[max_idx][1])
print("\nLowest similarity:")
print(y_s[min_idx])
print("y1:", reasonings[min_idx][0])
print("y2:", reasonings[min_idx][1])
# Out:
# Highest similarity:
# [[0.92132956]]
# y1: The system supports modifying user credentials and marking patients as deactivated, and role validation occurs during password reset, but there is no comprehensive workflow to modify access rights/roles across all workforce members, nor approval/audit for role changes beyond basic logging.
# y2: The application does not provide a way to modify that user’s access or role or disable the account. The only in-app changes that affect access are contextual assignments (e.g., hospital/ward assignments, declared HCPs per patient), which determine where and for whom a user operates. However, the system does not provide robust policy or approval workflows for these actions; instead, it relies on personnel to manually modify authorization decisions.
#
# Lowest similarity:
# [[0.49662364]]
# y1: FORM auth in web.xml; password verification with salted SHA-256; login timeout policy
# y2: There is no mechanism to corroborate that ePHI has not been altered or destroyed in an unauthorized manner.

# %% [markdown]
# code location

# %%
y_p = []
y_r = []
y_f = []
y_s = []
reasonings = []


def intervals_overlap(list_a, list_b):
    def parse(intervals):
        intervals = [s if '-' in s else s + '-' + str(int(s)+1) for s in intervals]
        return [(int(s.split('-')[0]), int(s.split('-')[1])) for s in intervals]
    
    for a_start, a_end in parse(list_a):
        for b_start, b_end in parse(list_b):
            if a_start <= b_end and b_start <= a_end:
                return True
    return False    

for pid, responses in nfr_response.items():
    for response in responses:
        if response.get("is_attention_question", False):
            continue
        id = response['nfr_id']
        y1 = response["code_location"]
        y2 = GT[id]["code_location"]
        temp = []
        for code_r in y1:
            gt_found = False
            for code_gt in y2:
                code_r = code_r[code_r.find('/')+1:]
                code_r = code_r.replace(':', ' ')
                code_r_file = code_r[:code_r.find(' ')]
                code_r_line = code_r[1+ code_r.find(' '):].split(' ')
                code_gt_file = code_gt[:code_gt.find(' ')]
                code_gt_line = code_gt[1+ code_gt.find(' '):].split(' ')
                if code_r_file == code_gt_file:
                    if intervals_overlap(code_r_line, code_gt_line):
                        temp.append(code_gt)
                        gt_found = True
            if gt_found == False:
                temp.append(code_r)
            
        y1=temp

        if response['satisfaction_level'] == "Denied" or GT[id]['satisfaction_level'] == "Denied":
            continue
        
        y1 = set(y1)
        y2 = set(y2)

        # True Positive is intersection of y1 and y2
        TP = len(y1.intersection(y2))
        if TP == 0:
            p = 0
            r = 0
            f1 = 0
        else:
            p = TP/len(y1)
            r = TP/len(y2)
            f1 = 2 * ((p*r)/(p+r))

        y_p.append(p)
        y_r.append(r)
        y_f.append(f1)        
        reasonings.append((y1, y2))

print()
print(f"F1: {np.mean(y_f):.4f} ± {np.std(y_f):.4f}")
print(f"P:  {np.mean(y_p):.4f} ± {np.std(y_p):.4f}")
print(f"R:  {np.mean(y_r):.4f} ± {np.std(y_r):.4f}")
# Out:
# F1: 0.1512 ± 0.2553
# P:  0.1419 ± 0.2526
# R:  0.2025 ± 0.3517

# %%
import numpy as np

max_idx = np.argmax(y_f)
min_idx = np.argmin(y_f)


print("Highest similarity:")
print(y_f[max_idx])
print("y1:", reasonings[max_idx][0])
print("y2:", reasonings[max_idx][1])
print("\nLowest similarity:")
print(y_f[min_idx])
print("y1:", reasonings[min_idx][0])
print("y2:", reasonings[min_idx][1])
# Out:
# Highest similarity:
# 1.0
# y1: {'privacyPolicy.jsp 17-99'}
# y2: {'privacyPolicy.jsp 17-99'}
#
# Lowest similarity:
# 0
# y1: {'PatientDAO.java 300-468', 'EditRepresentativesAction.java 44-94'}
# y2: {'ViewPatientAction.java 54-55', 'ViewMyRecordsAction.java 67-77'}

# %%
import pandas as pd
rows = []
all_nfrs = sorted({r["nfr_id"] for responses in nfr_response.values() for r in responses if not r.get("is_attention_question", False)})
pids = sorted(nfr_response.keys())

for nfr_id in all_nfrs:
    row = {"NFR ID": nfr_id, "GT": GT[nfr_id]["satisfaction_level"]}
    for i, pid in enumerate(pids):
        pid_map = {r["nfr_id"]: r for r in nfr_response[pid] if not r.get("is_attention_question", False)}
        row[f"Participant {i+1}"] = pid_map.get(nfr_id, {}).get("satisfaction_level", "N/A")
    rows.append(row)

df_table = pd.DataFrame(rows).set_index("NFR ID")
print(df_table.to_string())
# Out:
#                       GT     Participant 1     Participant 2     Participant 3     Participant 4     Participant 5     Participant 6     Participant 7     Participant 8     Participant 9    Participant 10    Participant 11    Participant 12    Participant 13    Participant 14    Participant 15    Participant 16    Participant 17    Participant 18 Participant 19 Participant 20 Participant 21    Participant 22 Participant 23    Participant 24    Participant 25    Participant 26    Participant 27    Participant 28    Participant 29    Participant 30 Participant 31    Participant 32    Participant 33    Participant 34
# NFR ID
# 1              Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A  Weakly Satisfied            N/A               N/A  Weakly Satisfied               N/A               N/A               N/A  Weakly Satisfied               N/A            N/A               N/A               N/A               N/A
# 2              Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A  Weakly Satisfied            N/A               N/A         Satisfied               N/A               N/A               N/A  Weakly Satisfied               N/A            N/A               N/A               N/A               N/A
# 3              Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A  Weakly Satisfied            N/A               N/A         Satisfied               N/A               N/A               N/A  Weakly Satisfied               N/A            N/A               N/A               N/A               N/A
# 4              Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A  Weakly Satisfied            N/A               N/A  Weakly Satisfied               N/A               N/A               N/A  Weakly Satisfied               N/A            N/A               N/A               N/A               N/A
# 5          Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A  Weakly Satisfied            N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            Denied               N/A            N/A               N/A               N/A               N/A
# 6          Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A     Weakly Denied            N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            Denied               N/A            N/A               N/A               N/A               N/A
# 7          Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A            Denied            N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            Denied               N/A            N/A               N/A               N/A               N/A
# 8                 Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A     Weakly Denied            N/A               N/A         Satisfied               N/A               N/A               N/A  Weakly Satisfied               N/A            N/A               N/A               N/A               N/A
# 9                 Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A            Denied            N/A               N/A            Denied               N/A               N/A               N/A            Denied               N/A            N/A               N/A               N/A               N/A
# 10                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A            Denied            N/A               N/A            Denied               N/A               N/A               N/A            Denied               N/A            N/A               N/A               N/A               N/A
# 11                Denied               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A            Denied
# 12             Satisfied               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A  Weakly Satisfied
# 13             Satisfied               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A         Satisfied
# 14             Satisfied               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A  Weakly Satisfied
# 15             Satisfied               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A         Satisfied
# 16                Denied               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A            Denied
# 17             Satisfied               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A  Weakly Satisfied
# 18      Weakly Satisfied               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A     Weakly Denied
# 19                Denied               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A         Satisfied
# 20             Satisfied               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A         Satisfied
# 21      Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied            N/A               N/A               N/A               N/A
# 22             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied            N/A               N/A               N/A               N/A
# 23             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied            N/A               N/A               N/A               N/A
# 24                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied            N/A               N/A               N/A               N/A
# 25                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied            N/A               N/A               N/A               N/A
# 26             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied            N/A               N/A               N/A               N/A
# 27             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied            N/A               N/A               N/A               N/A
# 28                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied            N/A               N/A               N/A               N/A
# 29      Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied            N/A               N/A               N/A               N/A
# 30                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied            N/A               N/A               N/A               N/A
# 31             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A            N/A      Satisfied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 32             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A            N/A      Satisfied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 33             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A            N/A      Satisfied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 34             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A            N/A      Satisfied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 35             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A            N/A      Satisfied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 36             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A            N/A      Satisfied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 37                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A         Denied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 38                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A         Denied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 39                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A         Denied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 40                Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A         Denied            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 41         Weakly Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 42      Weakly Satisfied               N/A               N/A               N/A               N/A               N/A            Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 43         Weakly Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 44             Satisfied               N/A               N/A               N/A               N/A               N/A            Denied               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 45         Weakly Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 46                Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 47                Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 48                Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 49             Satisfied               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 50                Denied               N/A               N/A               N/A               N/A               N/A            Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 51         Weakly Denied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 52                Denied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 53             Satisfied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 54         Weakly Denied               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 55                Denied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 56                Denied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 57                Denied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 58                Denied               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 59                Denied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 60             Satisfied               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 61             Satisfied  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A            N/A               N/A               N/A               N/A
# 62             Satisfied  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A            N/A               N/A               N/A               N/A
# 63             Satisfied         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A            N/A               N/A               N/A               N/A
# 64             Satisfied  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A            N/A               N/A               N/A               N/A
# 65                Denied            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A               N/A               N/A               N/A
# 66         Weakly Denied            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A               N/A               N/A               N/A
# 67                Denied            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A               N/A               N/A               N/A
# 68                Denied            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A               N/A               N/A               N/A
# 69                Denied            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A               N/A               N/A               N/A
# 70                Denied            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A            N/A               N/A               N/A               N/A
# 71                Denied               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 72             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 73                Denied               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 74                Denied               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 75             Satisfied               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# ...
# 124            Satisfied               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Denied            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 125        Weakly Denied               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Denied            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 126        Weakly Denied               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Denied            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 127               Denied               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Denied            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 128        Weakly Denied               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A         Denied            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 129            Satisfied               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A         Denied            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 130               Denied               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A         Denied            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A               N/A               N/A
# 131               Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A  Weakly Satisfied               N/A               N/A
# 132               Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A  Weakly Satisfied               N/A               N/A
# 133               Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A  Weakly Satisfied               N/A               N/A
# 134               Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A  Weakly Satisfied               N/A               N/A
# 135        Weakly Denied               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A  Weakly Satisfied               N/A               N/A
# 136     Weakly Satisfied               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A  Weakly Satisfied               N/A               N/A
# 137        Weakly Denied               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A  Weakly Satisfied               N/A               N/A
# 138        Weakly Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A     Weakly Denied               N/A               N/A
# 139               Denied               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A     Weakly Denied               N/A               N/A
# 140     Weakly Satisfied               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A         Satisfied               N/A               N/A
# 141            Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A  Weakly Satisfied               N/A
# 142            Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A  Weakly Satisfied               N/A
# 143               Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A            Denied               N/A
# 144               Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A  Weakly Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A            Denied               N/A
# 145               Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A            Denied               N/A
# 146               Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A            Denied               N/A
# 147               Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A         Satisfied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A            Denied               N/A
# 148               Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A     Weakly Denied               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A            N/A            N/A               N/A            N/A               N/A               N/A               N/A               N/A               N/A               N/A               N/A            N/A               N/A            Denied               N/A
