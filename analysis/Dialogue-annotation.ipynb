# %%
import json

# Load conversation.json
with open('../data/5.all-data/conversation.json', 'r') as f:
    conversation_all = json.load(f)
print('conversation.json:', 'conversation', 'len =', len(conversation_all))

# Load demographic.json
with open('../data/5.all-data/demographics.json', 'r') as f:
    demographic_all = json.load(f)
print('demographics.json:', 'demographic', 'len =', len(demographic_all))

# Load nfr_responses.json
with open('../data/5.all-data/nfr_responses.json', 'r') as f:
    nfr_response_all = json.load(f)
print('nfr_responses.json:', 'nfr_response', 'len =', len(nfr_response_all))

# Load satisfaction_survey.json
with open('../data/5.all-data/satisfaction_survey.json', 'r') as f:
    satisfaction_all = json.load(f)
print('satisfaction_survey.json:', 'satisfaction', 'len =', len(satisfaction_all))

# Load conversation.json
with open('../data/8.annotated_data/conversations.json', 'r') as f:
    conversation = json.load(f)
print('conversation.json:', 'conversation', 'len =', len(conversation))

# Load nfr_responses.json
with open('../data/8.annotated_data/nfr_responses.json', 'r') as f:
    nfr_response = json.load(f)
print('nfr_responses.json:', 'nfr_response', 'len =', len(nfr_response))

pilot_uni = [
    "e7c3d057-f0bb-4f30-aea0-ab689f9412ac",
    "18d5b4e7-f5c2-4dd3-81d8-6f21ecc1962b",
    "2d83f401-5153-45ed-9078-1c31e035849a",
    "368b58b7-feed-445b-a0ab-0e0b2b65dc5a",
]
pilot_prolific = [
    "e6991c2e-926c-4445-aae9-10a75496945f",
    "b50b6c66-2252-47cf-a890-9f13757be68c",
    "78288bfa-e19e-4af8-acad-effa1e3aae35",
    "700f34fb-b376-44ef-98c3-a55a045abdd5",
]
study_prolific = [
    "7fe17f91-130a-4c4f-a0b8-443278009213",
"f9399963-3f69-43d2-8d9d-e0a573a9c35d",
"3292c831-2fc7-4a52-81c9-7aa63cac86e8",
"e4691f7a-773b-438b-a7db-fd4cb12dc37f",
"397d6632-4575-4fb1-bbe4-b752e201a4bd",
"4274f797-dc8b-4127-bb50-bcf5c4a2e2bd",
"b4b276ed-55d1-4874-b61c-e47d9075125a",
"e9d46a67-49a6-445b-a851-46effd7e101c",
"0bd8d561-486c-45e5-8722-7048d22ce8e5",
"9a5f8d45-6bf0-4f1e-aadb-9011d213e24b",
"456bc583-cfbd-43c6-848c-f85006ad6e1f",
"c497b8f4-f74e-4979-9670-3fc496e09200",
"b2edd4e6-9b8f-43f4-bda5-77d43bcffc7e",
"1540a642-a495-4b83-ae3c-937a1aedf6ea",
"58d21f9f-8845-4f48-a523-6a85d220837d",
"996a0e8f-2294-4183-a4a2-c29e88930d65",
"4f99cde7-92af-4b5f-afcc-db146c3bba01",
"63f8d518-54ca-43aa-8a2f-68a165144b07",
"22438425-5563-4e62-929f-ed03b21ef583",
"13ce0d0c-67e9-422c-ac96-757d5bd3b837",
"99234c2d-5838-4f45-9a84-1eef505b4126",
"a85fbaef-eff6-4d7d-93d1-1017b8107bdc",
"3839c20d-a24f-49b8-b1a3-20f6eecac866",
"f384d13f-c84b-4163-a343-a035dbf5374f",
"04ac4c73-369b-4f7e-b5a7-a80597e93626",
"d05a5c3a-ab44-45b2-9437-b2698d86f52f",
"7ff75834-6394-4c93-9c99-b8859c5dbd7d",
"7958d91f-2dc8-4d9f-9bf0-6ea33fa3f927",
"bd165a59-c41e-4f93-9eaa-b34e19f4b7f6",
"977831a4-7811-4832-a8ed-fd4d830aaf18",
"71013647-e3d1-498e-afc3-ec1f4252cab7",
"b07644cc-9eda-4e68-b848-126831f7ad67",
"12c1fce4-4274-4df0-a964-427498920d15",
"f5c2ee02-60ba-4601-8659-ce3c65110b53",
"d4b12d74-82bd-4586-a6fd-5e701da1d253",
"e58ecbc0-6eda-433a-b765-b4d27976946c",
"25321c1d-2b9d-4762-877d-2b3f6d550a7d",
"1931388e-490b-478b-bb81-a66de854fea8",
"0133784d-c032-4518-97c6-b6b58fe671aa",
"d9675153-b7e3-47ed-98b0-f33fdc21456d",
"5ab35d1c-d7d0-422d-acb0-56e5c43b6817",
]

print('pilot_uni len =', len(pilot_uni))
print('pilot_prolific len =', len(pilot_prolific))
print('study_prolific len =', len(study_prolific))

# Assert no overlap between lists
assert not (set(pilot_uni) & set(pilot_prolific)), "pilot_uni and pilot_prolific have overlap!"
assert not (set(pilot_uni) & set(study_prolific)), "pilot_uni and study_prolific have overlap!"
assert not (set(pilot_prolific) & set(study_prolific)), "pilot_prolific and study_prolific have overlap!"
print('No overlap between pilot_uni, pilot_prolific, and study_prolific.')
# Out:
# conversation.json: conversation len = 49
# demographics.json: demographic len = 49
# nfr_responses.json: nfr_response len = 49
# satisfaction_survey.json: satisfaction len = 49
# conversation.json: conversation len = 34
# nfr_responses.json: nfr_response len = 34
# pilot_uni len = 4
# pilot_prolific len = 4
# study_prolific len = 41
# No overlap between pilot_uni, pilot_prolific, and study_prolific.

# %% [markdown]
# # Dialogue statistics

# %%
avg_turns_per_dialogue = []
avg_words_in_prompt = []
max_words_in_prompt = []
avg_words_in_response = []
max_words_in_response = []
avg_words_per_turn = []
max_words_per_turn = []
total_dialogues = []
total_turns = []

min_words_in_prompt = []
min_words_in_response = []
min_words_per_turn = []

for dialogue in conversation.values():
    avg_turns_per_dialogue.append(len(dialogue))

    prompt_word_counts = []
    response_word_counts = []
    turn_word_counts = []

    for turn in dialogue:
        p_words = len(turn["user_message"].split())
        r_words = len(turn["bot_reply"].split())

        prompt_word_counts.append(p_words)
        response_word_counts.append(r_words)
        turn_word_counts.append(p_words + r_words)

    avg_words_in_prompt.append(sum(prompt_word_counts) / len(prompt_word_counts))
    max_words_in_prompt.append(max(prompt_word_counts))
    avg_words_in_response.append(sum(response_word_counts) / len(response_word_counts))
    max_words_in_response.append(max(response_word_counts))
    avg_words_per_turn.append(sum(turn_word_counts) / len(turn_word_counts))
    max_words_per_turn.append(max(turn_word_counts))
    min_words_in_prompt.append(min(prompt_word_counts))
    min_words_in_response.append(min(response_word_counts))
    min_words_per_turn.append(min(turn_word_counts))

total_dialogues = len(conversation)
total_turns = sum(avg_turns_per_dialogue)

print(f"Total Dialogues: {total_dialogues}")
print(f"Total Turns: {total_turns}")
print(f"Avg Turns per Dialogue: {sum(avg_turns_per_dialogue) / len(avg_turns_per_dialogue):.2f}")
print(f"Avg Words in Prompt: {sum(avg_words_in_prompt) / len(avg_words_in_prompt):.2f}")
print(f"Max Words in Prompt: {max(max_words_in_prompt)}")
print(f"Avg Words in Response: {sum(avg_words_in_response) / len(avg_words_in_response):.2f}")
print(f"Max Words in Response: {max(max_words_in_response)}")
print(f"Avg Words per Turn: {sum(avg_words_per_turn) / len(avg_words_per_turn):.2f}")
print(f"Max Words per Turn: {max(max_words_per_turn)}")

print(f"Min Turns per Dialogue: {min(avg_turns_per_dialogue)}")
print(f"Min Words in Prompt: {min(min_words_in_prompt)}")
print(f"Min Words in Response: {min(min_words_in_response)}")
print(f"Min Words per Turn: {min(min_words_per_turn)}")
# Out:
# Total Dialogues: 34
# Total Turns: 406
# Avg Turns per Dialogue: 11.94
# Avg Words in Prompt: 60.90
# Max Words in Prompt: 495
# Avg Words in Response: 129.46
# Max Words in Response: 877
# Avg Words per Turn: 190.36
# Max Words per Turn: 1206
# Min Turns per Dialogue: 2
# Min Words in Prompt: 1
# Min Words in Response: 3
# Min Words per Turn: 5

# %%
from datetime import datetime

header = (
    f"{'UUID':<40} {'Start':<20} {'End':<20} {'Duration':<10} {'Turns':>5} "
    f"{'Turn Min':>8} {'Turn Max':>8} {'Turn Avg':>8} "
    f"{'Req Min':>7} {'Req Max':>7} {'Req Avg':>7} "
    f"{'Res Min':>7} {'Res Max':>7} {'Res Avg':>7}"
)
print(header)
print("-" * len(header))

for dialogue_id, dialogue in conversation.items():
    num_turns = len(dialogue)

    prompt_word_counts = []
    response_word_counts = []
    turn_word_counts = []

    for turn in dialogue:
        p_words = len(turn["user_message"].split())
        r_words = len(turn["bot_reply"].split())
        prompt_word_counts.append(p_words)
        response_word_counts.append(r_words)
        turn_word_counts.append(p_words + r_words)

    start = datetime.fromisoformat(dialogue[0]["user_time"])
    end = datetime.fromisoformat(dialogue[-1]["bot_time"])
    duration = str(end - start).split(".")[0]  # drop microseconds

    print(
        f"{dialogue_id:<40} {start.strftime('%Y-%m-%d %H:%M'):<20} {end.strftime('%Y-%m-%d %H:%M'):<20} {duration:<10} {num_turns:>5} "
        f"{min(turn_word_counts):>8} {max(turn_word_counts):>8} {sum(turn_word_counts)/len(turn_word_counts):>8.1f} "
        f"{min(prompt_word_counts):>7} {max(prompt_word_counts):>7} {sum(prompt_word_counts)/len(prompt_word_counts):>7.1f} "
        f"{min(response_word_counts):>7} {max(response_word_counts):>7} {sum(response_word_counts)/len(response_word_counts):>7.1f}"
    )
# Out:
# UUID                                     Start                End                  Duration   Turns Turn Min Turn Max Turn Avg Req Min Req Max Req Avg Res Min Res Max Res Avg
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# e7c3d057-f0bb-4f30-aea0-ab689f9412ac     2026-03-10 18:57     2026-03-10 19:30     0:33:05       21       60      366    108.0       7     267    35.5      48     127    72.5
# e6991c2e-926c-4445-aae9-10a75496945f     2026-03-18 21:27     2026-03-18 22:24     0:56:52       25       53      398    136.2      10     180    33.8      35     243   102.4
# b50b6c66-2252-47cf-a890-9f13757be68c     2026-03-18 22:17     2026-03-18 22:59     0:41:32       22       24      132     67.4       1      20     9.4      23     122    58.0
# ...

# %%
max_prompt = 0
min_prompt = float('inf')
max_response = 0
min_response = float('inf')

for dialogue in conversation.values():
    for turn in dialogue:
        p_words = len(turn["user_message"].split())
        r_words = len(turn["bot_reply"].split())

        max_prompt = max(max_prompt, p_words)
        min_prompt = min(min_prompt, p_words)
        max_response = max(max_response, r_words)
        min_response = min(min_response, r_words)

print(f"Max Words in a Single Prompt: {max_prompt}")
print(f"Min Words in a Single Prompt: {min_prompt}")
print(f"Max Words in a Single Response: {max_response}")
print(f"Min Words in a Single Response: {min_response}")
# Out:
# Max Words in a Single Prompt: 495
# Min Words in a Single Prompt: 1
# Max Words in a Single Response: 877
# Min Words in a Single Response: 3

# %%
min_prompt_text = ""
max_prompt_text = ""
min_response_text = ""
max_response_text = ""
min_prompt_len = float('inf')
max_prompt_len = 0
min_response_len = float('inf')
max_response_len = 0

for dialogue in conversation.values():
    for turn in dialogue:
        p_words = len(turn["user_message"].split())
        r_words = len(turn["bot_reply"].split())

        if p_words < min_prompt_len:
            min_prompt_len = p_words
            min_prompt_text = turn["user_message"]
        if p_words > max_prompt_len:
            max_prompt_len = p_words
            max_prompt_text = turn["user_message"]
        if r_words < min_response_len:
            min_response_len = r_words
            min_response_text = turn["bot_reply"]
        if r_words > max_response_len:
            max_response_len = r_words
            max_response_text = turn["bot_reply"]

print(f"Min Response ({min_response_len} words):\n{min_response_text}\n")
print('*'*50)
print(f"Max Response ({max_response_len} words):\n{max_response_text}\n")
print('*'*50)
print(f"Min Prompt ({min_prompt_len} words):\n{min_prompt_text}\n")
print('*'*50)
print(f"Max Prompt ({max_prompt_len} words):\n{max_prompt_text}\n")
# Out:
# Min Response (3 words):
# Anytime—happy to help.
#
# **************************************************
# Max Response (877 words):
# Searching the repository for code, tests, or docs mentioning PHI, disclosure, access, amendment, restrictions, designated records, accounting, and audit so each NFR can be mapped to files/lines. Running multiple ripgrep searches in parallel plus reporting intent.
#
# Running repository-wide searches for keywords related to access, accounting, amendments, restrictions, disclosures, audits, and transactions to map each NFR to code locations. This will provide evidence lines to evaluate satisfaction.
#
# Summary evaluation (evidence lines reference repo files). Confidence: High = strong code/tests present; Medium = partial support/policy only; Low = absence detection less-certain.
#
# NFR 61 — incidental uses allowed only when underlying use/disclosure permitted
# - Satisfaction: Weakly Satisfied
# ...
