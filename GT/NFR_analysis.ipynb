# %%
import json
with open('NFR_balancedt4.json', 'r') as file:
        data = json.load(file)

# %%
sls = {}
for b in data:
    for nfr in b:
        sl = nfr.get('satisfaction_level')
        sls[sl] = sls.get(sl, 0) + 1
sls
# Out:
# {'Satisfied': 49,
#  'Weakly Denied': 20,
#  'Denied': 69,
#  'Weakly Satisfied': 10,
#  'NA': 32}

# %%
data1 = []
i = 0
temp = []
for b in data:
    for nfr in b:

        if not nfr.get('satisfaction_level'):
            i += 1
            print(i, nfr['id'])
# Out:
# 0

# %%
i
# Out:
# 21

# %%
raise Exception('stop')
with open('NFR_balancedt4.json', 'w') as f:
    json.dump(data1, f, indent=4, ensure_ascii=False)
