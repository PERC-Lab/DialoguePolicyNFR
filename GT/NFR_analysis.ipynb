# %%
import json
with open('NFR_balancedt7.json', 'r') as file:
        data = json.load(file)

# %%
'''
data1 = []
for b in data:
    for nfr in b:
        if nfr['satisfaction_level'] != "NA":
            data1.append(nfr)
'''
i = 0
for b in data:
    if len(b) != 10:
        print(b[0]['legacy_id'],'--------')
    for nfr in b:
        i+=1
        sl = nfr["id"] = i
# Out:
# 64 --------

# %%
with open('NFR_balancedt8.json', 'w') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)
